# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
ibon = pd.read_csv('datasets\\penguins.csv')

# %%
ibon
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %%
ibon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
ibon.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
ibon.isnull()
# Out:
#      rowid  species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    False    False   False           False          False              False
# 1    False    False   False           False          False              False
# 2    False    False   False           False          False              False
# 3    False    False   False            True           True               True
# 4    False    False   False           False          False              False
# ..     ...      ...     ...             ...            ...                ...
# 339  False    False   False           False          False              False
# 340  False    False   False           False          False              False
# 341  False    False   False           False          False              False
# 342  False    False   False           False          False              False
# 343  False    False   False           False          False              False
#
#      body_mass_g    sex   year
# ...

# %%
ibon.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h1>Descriptive Analytics</h1>

# %%
ibon.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
ibon.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# rowid              344.0   172.500000   99.448479     1.0    86.750   172.50
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                        75%     max
# rowid               258.25   344.0
# bill_length_mm       48.50    59.6
# bill_depth_mm        18.70    21.5
# flipper_length_mm   213.00   231.0
# body_mass_g        4750.00  6300.0
# year               2009.00  2009.0

# %% [markdown]
# <h1>FILTERING DATA BASED FROM COLUMNS</h1>

# %%
ibon['year']
# Out:
# 0      2007
# 1      2007
# 2      2007
# 3      2007
# 4      2007
#        ...
# 339    2009
# 340    2009
# 341    2009
# 342    2009
# 343    2009
# Name: year, Length: 344, dtype: int64

# %% [markdown]
# <h1>HOW TO DEFINE / CREATE YOUR OWN COLUMN</h1>

# %%
ibon['weight'] = ibon['body_mass_g'] / 1000

# %%
ibon
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007   3.750
# 1                186.0       3800.0  female  2007   3.800
# ...

# %%
ibon['weight'] = np.round(ibon['body_mass_g'] / 1000,1)

# %%
ibon
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007     3.8
# 1                186.0       3800.0  female  2007     3.8
# ...

# %%
ibon.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %% [markdown]
# <h1>WHAT TO DO WITH NULL VALUES </h1>
#
# <p>Delete the Row</p>
# <p>Fill the empty cells with a value</p>

# %%
ibon['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
ibon['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
ibon['bill_length_mm'] = ibon['bill_length_mm'].fillna(ibon['bill_length_mm'].mean())

# %%
ibon
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000           18.7
# 1        2     Adelie  Torgersen        39.50000           17.4
# 2        3     Adelie  Torgersen        40.30000           18.0
# 3        4     Adelie  Torgersen        43.92193            NaN
# 4        5     Adelie  Torgersen        36.70000           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000           19.8
# 340    341  Chinstrap      Dream        43.50000           18.1
# 341    342  Chinstrap      Dream        49.60000           18.2
# 342    343  Chinstrap      Dream        50.80000           19.0
# 343    344  Chinstrap      Dream        50.20000           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007     3.8
# 1                186.0       3800.0  female  2007     3.8
# ...

# %%
ibon['body_mass_g'] = ibon['body_mass_g'].fillna(ibon['body_mass_g'].mean())

# %%
ibon
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000           18.7
# 1        2     Adelie  Torgersen        39.50000           17.4
# 2        3     Adelie  Torgersen        40.30000           18.0
# 3        4     Adelie  Torgersen        43.92193            NaN
# 4        5     Adelie  Torgersen        36.70000           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000           19.8
# 340    341  Chinstrap      Dream        43.50000           18.1
# 341    342  Chinstrap      Dream        49.60000           18.2
# 342    343  Chinstrap      Dream        50.80000           19.0
# 343    344  Chinstrap      Dream        50.20000           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0  3750.000000    male  2007     3.8
# 1                186.0  3800.000000  female  2007     3.8
# ...

# %%
ibon.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           0
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %%
ibon['sex'] = ibon['sex'].fillna(ibon['sex'].mode()[0])

# %%
ibon
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000           18.7
# 1        2     Adelie  Torgersen        39.50000           17.4
# 2        3     Adelie  Torgersen        40.30000           18.0
# 3        4     Adelie  Torgersen        43.92193            NaN
# 4        5     Adelie  Torgersen        36.70000           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000           19.8
# 340    341  Chinstrap      Dream        43.50000           18.1
# 341    342  Chinstrap      Dream        49.60000           18.2
# 342    343  Chinstrap      Dream        50.80000           19.0
# 343    344  Chinstrap      Dream        50.20000           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0  3750.000000    male  2007     3.8
# 1                186.0  3800.000000  female  2007     3.8
# ...

# %%
ibon.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          0
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
ibon['body_mass_g'] = ibon['body_mass_g'].fillna(ibon['body_mass_g'].mode()[0])

# %%
ibon
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000           18.7
# 1        2     Adelie  Torgersen        39.50000           17.4
# 2        3     Adelie  Torgersen        40.30000           18.0
# 3        4     Adelie  Torgersen        43.92193            NaN
# 4        5     Adelie  Torgersen        36.70000           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000           19.8
# 340    341  Chinstrap      Dream        43.50000           18.1
# 341    342  Chinstrap      Dream        49.60000           18.2
# 342    343  Chinstrap      Dream        50.80000           19.0
# 343    344  Chinstrap      Dream        50.20000           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0  3750.000000    male  2007     3.8
# 1                186.0  3800.000000  female  2007     3.8
# ...

# %%
ibon.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          0
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
ibon['body_mass_g'] = ibon['body_mass_g'].fillna(ibon['body_mass_g'].mean())

# %%
ibon
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000           18.7
# 1        2     Adelie  Torgersen        39.50000           17.4
# 2        3     Adelie  Torgersen        40.30000           18.0
# 3        4     Adelie  Torgersen        43.92193            NaN
# 4        5     Adelie  Torgersen        36.70000           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000           19.8
# 340    341  Chinstrap      Dream        43.50000           18.1
# 341    342  Chinstrap      Dream        49.60000           18.2
# 342    343  Chinstrap      Dream        50.80000           19.0
# 343    344  Chinstrap      Dream        50.20000           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0  3750.000000    male  2007     3.8
# 1                186.0  3800.000000  female  2007     3.8
# ...

# %%
ibon.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          0
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
ibon['weight'] = ibon['weight'].fillna(ibon['weight'].mean())

# %%
ibon
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000           18.7
# 1        2     Adelie  Torgersen        39.50000           17.4
# 2        3     Adelie  Torgersen        40.30000           18.0
# 3        4     Adelie  Torgersen        43.92193            NaN
# 4        5     Adelie  Torgersen        36.70000           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000           19.8
# 340    341  Chinstrap      Dream        43.50000           18.1
# 341    342  Chinstrap      Dream        49.60000           18.2
# 342    343  Chinstrap      Dream        50.80000           19.0
# 343    344  Chinstrap      Dream        50.20000           18.7
#
#      flipper_length_mm  body_mass_g     sex  year    weight
# 0                181.0  3750.000000    male  2007  3.800000
# 1                186.0  3800.000000  female  2007  3.800000
# ...

# %%
ibon.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %%
ibon['flipper_length_mm'] = ibon['flipper_length_mm'].fillna(ibon['flipper_length_mm'].mean())

# %%
ibon
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000           18.7
# 1        2     Adelie  Torgersen        39.50000           17.4
# 2        3     Adelie  Torgersen        40.30000           18.0
# 3        4     Adelie  Torgersen        43.92193            NaN
# 4        5     Adelie  Torgersen        36.70000           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000           19.8
# 340    341  Chinstrap      Dream        43.50000           18.1
# 341    342  Chinstrap      Dream        49.60000           18.2
# 342    343  Chinstrap      Dream        50.80000           19.0
# 343    344  Chinstrap      Dream        50.20000           18.7
#
#      flipper_length_mm  body_mass_g     sex  year    weight
# 0           181.000000  3750.000000    male  2007  3.800000
# 1           186.000000  3800.000000  female  2007  3.800000
# ...

# %%
ibon.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %%
ibon['bill_depth_mm'] = ibon['bill_depth_mm'].fillna(ibon['bill_depth_mm'].mean())

# %%
ibon
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 1        2     Adelie  Torgersen        39.50000       17.40000
# 2        3     Adelie  Torgersen        40.30000       18.00000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 4        5     Adelie  Torgersen        36.70000       19.30000
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000       19.80000
# 340    341  Chinstrap      Dream        43.50000       18.10000
# 341    342  Chinstrap      Dream        49.60000       18.20000
# 342    343  Chinstrap      Dream        50.80000       19.00000
# 343    344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year    weight
# 0           181.000000  3750.000000    male  2007  3.800000
# 1           186.000000  3800.000000  female  2007  3.800000
# ...

# %%
ibon.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %%
ibon['year'] = ibon['year'].astype('category')

# %%
ibon['species'] = ibon['species'].astype('category')

# %%
ibon['rowid'] = ibon['rowid'].astype('category')

# %%
ibon['island'] = ibon['island'].astype('category')

# %%
ibon['sex'] = ibon['sex'].astype('category')

# %%
ibon['species'] == "Chinstrap"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
ibon[ibon['species'] == "Adelie"].count()
# Out:
# rowid                152
# species              152
# island               152
# bill_length_mm       152
# bill_depth_mm        152
# flipper_length_mm    152
# body_mass_g          152
# sex                  152
# year                 152
# weight               152
# dtype: int64

# %%
ibon[ibon['species'] == "Chinstrap"].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                  68
# year                 68
# weight               68
# dtype: int64

# %% [markdown]
# <h1>GENTOO SPECIES HAVE WEIGHT MORE THAN 3KG?</h1>

# %%
ibon['species'] == "Gentoo"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
ibon['body_mass_g'] > 3000
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 339    True
# 340    True
# 341    True
# 342    True
# 343    True
# Name: body_mass_g, Length: 344, dtype: bool

# %% [markdown]
# <h1>Insight no. 1</h1>
# <h2>Gentoo live exclusively on the Biscoe Island</h2>

# %%
ibon_tor = ibon[(ibon['species'] == 'Adelie') & (ibon['island'] == 'Torgersen')]

# %%
ibon_biscoe = ibon[(ibon['species'] == 'Adelie') & (ibon['island'] == 'Biscoe')]

# %%
ibon_dream = ibon[(ibon['species'] == 'Adelie') & (ibon['island'] == 'Dream')]

# %%
ibon_dream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, 30 to 151
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              56 non-null     category
#  1   species            56 non-null     category
#  2   island             56 non-null     category
#  3   bill_length_mm     56 non-null     float64
#  4   bill_depth_mm      56 non-null     float64
#  5   flipper_length_mm  56 non-null     float64
#  6   body_mass_g        56 non-null     float64
#  7   sex                56 non-null     category
#  8   year               56 non-null     category
#  9   weight             56 non-null     float64
# dtypes: category(5), float64(5)
# memory usage: 14.2 KB

# %% [markdown]
# <h1>Insight no. 2</h1>
# <h2>The specie Adelie lives on 3 Islands</h2>
# <h1>Does the isand impact the body mass of penguin specie</h1>

# %%
ibon_dream_w = np.round(ibon_dream['body_mass_g'].mean(), 1)

# %%
ibon_dream_w
# Out:
# np.float64(3688.4)

# %% [markdown]
# <h1>Insight no. 3</h1>
#
# <h1>The specie chinstrap Only live in one island</h1>

# %%
ibon_dream = ibon[(ibon['island'] == 'Dream') & (ibon['species'] == 'Chinstrap')]

# %%
ibon_dream
# Out:
#     rowid    species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276   277  Chinstrap  Dream            46.5           17.9              192.0
# 277   278  Chinstrap  Dream            50.0           19.5              196.0
# 278   279  Chinstrap  Dream            51.3           19.2              193.0
# 279   280  Chinstrap  Dream            45.4           18.7              188.0
# 280   281  Chinstrap  Dream            52.7           19.8              197.0
# ..    ...        ...    ...             ...            ...                ...
# 339   340  Chinstrap  Dream            55.8           19.8              207.0
# 340   341  Chinstrap  Dream            43.5           18.1              202.0
# 341   342  Chinstrap  Dream            49.6           18.2              193.0
# 342   343  Chinstrap  Dream            50.8           19.0              210.0
# 343   344  Chinstrap  Dream            50.2           18.7              198.0
#
# ...

# %% [markdown]
# <h1>Insight No.4</h1>
#
# <h1>Does the weight hae an impact?</h1>
# <h2>Chinstrap weight</h2>

# %%
ibon['weight'] = np.round(ibon['body_mass_g'] / 1000, 2)

# %% [markdown]
# <h2>Adelies in each island</h2>

# %%
ade = np.round(ibon['weight'].mean(),1)

# %%
ade
# Out:
# np.float64(4.2)

# %% [markdown]
# <h1>Insight No. 5</h1>
# <h2>There is a significant impoact on weight of Gentoo for each island due to its exclusiveness</h2>

# %%
chin_bis = np.round(ibon['weight'].mean(),1)

# %%
chin_bis
# Out:
# np.float64(4.2)

# %%
chin_dre = np.round(ibon['weight'].mean(),1)

# %%
chin_dre
# Out:
# np.float64(4.2)

# %%
chin_tor = np.round(ibon['weight'].mean(),1)

# %%
chin_tor
# Out:
# np.float64(4.2)

# %% [markdown]
# <h1>Insight No. 6</h1>
# <h2>Chinstrap's weight remain average and does not have a significant impact</h2>

# %% [markdown]
# <h1>Insight No. 7</h1>
# <h2>Gentoo have the heaviest weight with the average of 5.1 kilograms</h2>

# %% [markdown]
# <h1>AGGREGATING DATA</h1>
#
# <h2>Insight No. 8</h2>
#
# <h3>Wahat year has the highest recorded male '->'Adelie' and in what island</h3>

# %%
male_ade = ibon.groupby(['species', 'sex', 'island']).size()
# Out:
# C:\Users\LAB4-StudentPC47\AppData\Local\Temp\ipykernel_2448\3764324226.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   male_ade = ibon.groupby(['species', 'sex', 'island']).size()

# %%
male_ade
# Out:
# species    sex     island
# Adelie     female  Biscoe       22
#                    Dream        27
#                    Torgersen    24
#            male    Biscoe       22
#                    Dream        29
#                    Torgersen    28
# Chinstrap  female  Biscoe        0
#                    Dream        34
#                    Torgersen     0
#            male    Biscoe        0
#                    Dream        34
#                    Torgersen     0
# Gentoo     female  Biscoe       58
#                    Dream         0
#                    Torgersen     0
#            male    Biscoe       66
#                    Dream         0
#                    Torgersen     0
# dtype: int64

# %% [markdown]
# <h1>Insight No. 9</h1>
#
# <h2>Which is more heavier in each birds (Female/Male)</h2>

# %%
ibon.columns
# Out:
# Index(['rowid', 'species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year', 'weight'],
#       dtype='object')

# %%
ibon_F_M_W = np.round(ibon.groupby(['species', 'sex'])['weight'].mean(),1)
# Out:
# C:\Users\LAB4-StudentPC47\AppData\Local\Temp\ipykernel_2448\2595599820.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ibon_F_M_W = np.round(ibon.groupby(['species', 'sex'])['weight'].mean(),1)

# %%
ibon_F_M_W.unstack()
# Out:
# sex        female  male
# species
# Adelie        3.4   4.0
# Chinstrap     3.5   3.9
# Gentoo        4.7   5.4

# %% [markdown]
# <h1 style='font-size: 100px>Overall</h1>
#
# <h2>1. Insight no. 9</h2>
# <h3>Average weight: 4,0kg</h3>
# <h3>Male Adelie are heavier</h3>
#
# <h2>2. Insight no. 10</h2>
# <h3>Average weight: 3,9kg</h3>
# <h3>Male chinstrap are heavier</h3>
#
# <h2>3. Insight no. 11</h2>
# <h3>Average weight: 5,4kg</h3>
# <h3>Male Gentoo are heavier</h3>
#
# <h2>Male are more dominant in terms of weight</h2>

# %% [markdown]
# <h1 style='font-size: 80px; color: red;'>OVERALL</h1>
# <ul>
#     <li>
#         <h1 style='font-size: 50px; color: orange;'>Insight No. 9</h1>
#         <h2>Female average weight: 3.4kgs</h2>
#         <h2>Male average weight: 4.0kgs</h2>
#         <h1 style='font-size: 20px; color: blue;'>Male Adelie are heavier</h1>
#     </li>
# </ul>
# <br>
# <ul>
#     <li>
#         <h1 style='font-size: 50px; color: orange;'>Insight No. 10</h1>
#         <h2>Female average weight: 3.5kgs</h2>
#         <h2>Male average weight: 3.9kgs</h2>
#         <h1 style='font-size: 20px; color: blue;'>Male Chinstrap are heavier</h1>
#     </li>
# </ul>
# <br>
# <ul>
#     <li>
#         <h1 style='font-size: 50px; color: orange;'>Insight No. 11</h1><br>
#         <h2>Female average weight: 4.7kgs</h2>
#         <h2>Male average weight: 5.4kgs</h2>
#         <h1 style='font-size: 20px; color: blue;'>Male Gentoo are heavier</h1>
#     </li>
# <br>
# <li>
#     <h1 style='font-size: 80px; color: red;'>Conclusion:</h1>
#     <h2 style='font-size: 40px; color: #2b2b2b;'>Male are more dominant in terms of weight</h2>
# </li>

# %% [markdown]
# <h1 style='font-size: 80px; color: #800000'>Correlation</h1>
# <h1>Correlation using Python and Pandas</h1>
#
# <h3>Requirement for correlation</h3>
# <ul>
#     <li>
#         Name the correlation
#     </li>
# </ul>
# <ul>
#     <li>
#         Call the first column
#     </li>
# </ul>
# <ul>
#     <li>
#         Test Correlation using .corr() function
#     </li>
# </ul>
# <ul>
#     <li>
#         Call the second column
#     </li>
# </ul>

# %% [markdown]
# <h1 style='font-size: 50px; color: Orange'>Does the bill length affects the size of the depth?</h1>

# %%
b_depp = ibon['bill_length_mm'].corr(ibon['bill_depth_mm'])

# %%
b_depp
# Out:
# np.float64(-0.23505287035553282)

# %% [markdown]
# <h1>Insight No. 12</h1>
# <h2>There is no correlation</h2>

# %%
flip_depp = ibon['bill_length_mm'].corr(ibon['flipper_length_mm'])

# %%
flip_depp
# Out:
# np.float64(0.6561813407464278)

# %% [markdown]
# <h1>Insight No. 13</h1>
# <h2>There is acorrelation</h2>

# %%
body_depp = ibon['bill_length_mm'].corr(ibon['body_mass_g'])

# %%
body_depp
# Out:
# np.float64(0.5951098244376304)

# %% [markdown]
# <h1>Insight No. 14</h1>
# <h2>There is a correlation</h2>

# %%
ibon
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000       18.70000
# 1       2     Adelie  Torgersen        39.50000       17.40000
# 2       3     Adelie  Torgersen        40.30000       18.00000
# 3       4     Adelie  Torgersen        43.92193       17.15117
# 4       5     Adelie  Torgersen        36.70000       19.30000
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream        55.80000       19.80000
# 340   341  Chinstrap      Dream        43.50000       18.10000
# 341   342  Chinstrap      Dream        49.60000       18.20000
# 342   343  Chinstrap      Dream        50.80000       19.00000
# 343   344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0           181.000000  3750.000000    male  2007    3.75
# 1           186.000000  3800.000000  female  2007    3.80
# ...

# %%
billd_depp = ibon['bill_depth_mm'].corr(ibon['flipper_length_mm'])

# %%
billd_depp
# Out:
# np.float64(-0.5838512164654122)

# %% [markdown]
# <h1>Insight No. 15</h1>
# <h2>There is a correlation</h2>
